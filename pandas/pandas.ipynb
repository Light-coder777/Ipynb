# %% [markdown]
# <a href="https://colab.research.google.com/github/Light-coder777/Ipynb/blob/main/pandas/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re

# %%
txt = '''Now is the winter of our discontent
Made glorious summer by this sun of York;
And all the clouds that lour'd upon our house
In the deep bosom of the ocean buried.
Now are our brows bound with victorious wreaths;
Our bruised arms hung up for monuments;
Our stern alarums changed to merry meetings,
Our dreadful marches to delightful measures.
Grim-visaged war hath smooth'd his wrinkled front;
And now, instead of mounting barded steeds
To fright the souls of fearful adversaries,
He capers nimbly in a lady's chamber
To the lascivious pleasing of a lute.
But I, that am not shaped for sportive tricks,
Nor made to court an amorous souls looking-glass;
I, that am rudely stamp'd, and want love's mam'''

# %%
find = re.search("am",txt)
find
# Out:
# <re.Match object; span=(511, 513), match='am'>

# %%
find = re.findall("am",txt)

# %%
len(re.split("am",txt))
# Out:
# 7

# %%
re.findall("souls",txt)
# Out:
# ['souls', 'souls']

# %%
len(re.findall("\s",txt))
# Out:
# 120

# %%
len(re.findall(".",txt))
# Out:
# 683

# %%
url = ' 9971-5-0210-0'
url = '960-425-059-0'
pattern = '^www.[\w\d]*.com'
pattern = '[\d]{4}-\d-[\d]{4}-\d|[\d]{3}-[\d]{3}-[\d]{3}-\d'
re.findall(pattern,url)
# Out:
# ['960-425-059-0']

# %%
url = '960-425-059-0'
pattern = '^doi'
re.findall(pattern,url)

# %%
a1 = np.random.rand(4)
a2 = np.random.rand(4, 1)
a3 = np.array([[1, 2, 3, 4]])
a4 = np.arange(1, 4, 1)
a5 = np.linspace(1 ,4, 4)

# %%
t1 = '''Office of Research Administration: (734) 647-6333 | 4325 North Quad
Office of Budget and Financial Administration: (734) 647-8044 | 309 Maynard, Suite 205
Health Informatics Program: (734) 763-2285 | 333 Maynard, Suite 500
Office of the Dean: (734) 647-3576 | 4322 North Quad
UMSI Engagement Center: (734) 763-1251 | 777 North University
Faculty Adminstrative Support Staff: (734) 764-9376 | 4322 North Quad'''

# %%
pat = '[(\d)]+ \d+\-\d{1,4} \| \d+'
pat = '[(]\d{3}[)]\d{3}[-]\d{4}'
re.findall(pat,t1)
# Out:
# []

# %%
import numpy as np
import pandas as pd
series =  pd.Series(np.random.randint(0,1000,10000))

# %%
series.head()
# Out:
# 0    611
# 1    548
# 2    703
# 3    265
# 4    285
# dtype: int64

# %%
# %%timeit -n 100
sum = 0
for i in series:
  sum += i
avg = sum/len(series)
# Out:
# 1.34 ms ± 40.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit -n 100
sum = np.sum(series)
avg = sum/len(series)
# Out:
# 67.6 µs ± 20.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit -n 10
series =  pd.Series(np.random.randint(0,1000,10000))
series += 2
# Out:
# 323 µs ± 183 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# here the computation is reduced due to the vectorization
# %%timeit -n 10
series = pd.Series(np.random.randint(0,10000,10000))
for label,value in series.iteritems():
  series[label] = value + 2
# Out:
# 54.2 ms ± 988 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# !wget https://raw.githubusercontent.com/srinivasav22/Graduate-Admission-Prediction/master/Admission_Predict_Ver1.1.csv
# !cat content/Admission_Predict_Ver1
# Out:
# --2022-10-08 14:28:09--  https://raw.githubusercontent.com/srinivasav22/Graduate-Admission-Prediction/master/Admission_Predict_Ver1.1.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16176 (16K) [text/plain]
# Saving to: ‘Admission_Predict_Ver1.1.csv’
#
# Admission_Predict_V 100%[===================>]  15.80K  --.-KB/s    in 0.001s
#
# 2022-10-08 14:28:09 (26.2 MB/s) - ‘Admission_Predict_Ver1.1.csv’ saved [16176/16176]
#
# cat: content/Admission_Predict_Ver1: No such file or directory

# %%
df = pd.read_csv('/content/Admission_Predict_Ver1.1.csv',index_col=0)
df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# 2                  1              0.76
# 3                  1              0.72
# 4                  1              0.80
# 5                  0              0.65

# %%
df.columns = [i.lower().strip() for i in df.columns]

# %%
df.head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 5                 314          103                  2  2.0  3.0  8.21
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.76
# 3                  1             0.72
# 4                  1             0.80
# 5                  0             0.65

# %%
# (df.cgpa > 0.7) and (df.cgpa < 0.9) we cant use and N or 
(df.cgpa > 0.7) & (df.cgpa < 0.9) # also we can use lt and gt in this
# Out:
# Serial No.
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 496    False
# 497    False
# 498    False
# 499    False
# 500    False
# Name: cgpa, Length: 500, dtype: bool

# %%
df.cgpa.lt(0.9).gt(0.7)
# Out:
# Serial No.
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 496    False
# 497    False
# 498    False
# 499    False
# 500    False
# Name: cgpa, Length: 500, dtype: bool

# %%
df.research.unique()
# Out:
# array([1, 0])

# %%
df = df.reset_index()

# %%
df.set_index(['Serial No.','research'])
# Out:
#                      gre score  toefl score  university rating  sop  lor  \
# Serial No. research
# 1          1               337          118                  4  4.5  4.5
# 2          1               324          107                  4  4.0  4.5
# 3          1               316          104                  3  3.0  3.5
# 4          1               322          110                  3  3.5  2.5
# 5          0               314          103                  2  2.0  3.0
# ...                        ...          ...                ...  ...  ...
# 496        1               332          108                  5  4.5  4.0
# 497        1               337          117                  5  5.0  5.0
# 498        1               330          120                  5  4.5  5.0
# 499        0               312          103                  4  4.0  5.0
# 500        0               327          113                  4  4.5  4.5
#
#                      cgpa  chance of admit
# Serial No. research
# ...

# %%
df.isna().sum()
# Out:
# Serial No.           0
# gre score            0
# toefl score          0
# university rating    0
# sop                  0
# lor                  0
# cgpa                 0
# research             0
# chance of admit      0
# dtype: int64

# %%
# ffill is applied and it fills the values from the previous values
df.fillna(method='ffill')
# Out:
#      Serial No.  gre score  toefl score  university rating  sop  lor  cgpa  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495         496        332          108                  5  4.5  4.0  9.02
# 496         497        337          117                  5  5.0  5.0  9.87
# 497         498        330          120                  5  4.5  5.0  9.56
# 498         499        312          103                  4  4.0  5.0  8.43
# 499         500        327          113                  4  4.5  4.5  9.04
#
#      research  chance of admit
# 0           1             0.92
# ...

# %%
""" using regex to change the values
  let us say if research is there then we will admit them
  so using the regex to replace it as no N yes"""

# df.replace(to_replace=1,value='yes',regex=True)
data = df.cgpa.replace(to_replace="[+-]?([0-9]*[.])?[0-9]+",value='1',regex=True) # dont know why its not working

# %%
data.head()
# Out:
# 0    9.65
# 1    8.87
# 2    8.00
# 3    8.67
# 4    8.21
# Name: cgpa, dtype: float64

# %%
# %%timeit -n 10
import re 
new = []
for i in df.cgpa:
  new.append(re.findall("[89]\.\d*",str(i)))
# Out:
# 2.59 ms ± 1.6 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit -n 10
temp = map(str,[i for i in df.cgpa])
txt = ' '.join(list(temp))
new2 = re.findall("[89]\.\d*",txt)
# Out:
# 1.08 ms ± 253 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit -n 10
# new2 = re.findall("[89]\.\d*",' '.join(map(str,[i for i in df.cgpa]))) # map is way faster
new2 = re.findall("[89]\.\d*",' '.join(list(temp))) # map is way faster
# new2 = re.findall("[89]\.\d*",' '.join(str(df.cgpa)))
# Out:
# 1.2 µs ± 357 ns per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
df.head()
# Out:
#    serial no.  gre score  toefl score  university rating  sop  lor  cgpa  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        324          107                  4  4.0  4.5  8.87
# 2           3        316          104                  3  3.0  3.5  8.00
# 3           4        322          110                  3  3.5  2.5  8.67
# 4           5        314          103                  2  2.0  3.0  8.21
#
#    research  chance of admit
# 0         1             0.92
# 1         1             0.76
# 2         1             0.72
# 3         1             0.80
# 4         0             0.65

# %%
df['english'] = df['toefl score']
df.head()
# Out:
#    serial no.  gre score  toefl score  university rating  sop  lor  cgpa  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        324          107                  4  4.0  4.5  8.87
# 2           3        316          104                  3  3.0  3.5  8.00
# 3           4        322          110                  3  3.5  2.5  8.67
# 4           5        314          103                  2  2.0  3.0  8.21
#
#    research  chance of admit  english
# 0         1             0.92      118
# 1         1             0.76      107
# 2         1             0.72      104
# 3         1             0.80      110
# 4         0             0.65      103

# %%
del(df['toefl score'])

# %%
df.head()
# Out:
#    serial no.  gre score  university rating  sop  lor  cgpa  research  \
# 0           1        337                  4  4.5  4.5  9.65         1
# 1           2        324                  4  4.0  4.5  8.87         1
# 2           3        316                  3  3.0  3.5  8.00         1
# 3           4        322                  3  3.5  2.5  8.67         1
# 4           5        314                  2  2.0  3.0  8.21         0
#
#    chance of admit  english
# 0             0.92      118
# 1             0.76      107
# 2             0.72      104
# 3             0.80      110
# 4             0.65      103

# %%
import pandas as pd
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
obj1 = pd.Series(sdata)
states = ['California', 'Ohio', 'Oregon', 'Texas']
obj2 = pd.Series(sdata, index=states)
obj2 == None
# Out:
# California    False
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
None == Nan

# %%
import numpy as np
import pandas as pd

# %%
from IPython.display import clear_output
# !wget https://censusindia.gov.in/nada/index.php/catalog/42526/download/46152/A-1_NO_OF_VILLAGES_TOWNS_HOUSEHOLDS_POPULATION_AND_AREA.xlsx
# clear_output()
# Out:
# --2022-10-09 04:01:41--  https://censusindia.gov.in/nada/index.php/catalog/42526/download/46152/A-1_NO_OF_VILLAGES_TOWNS_HOUSEHOLDS_POPULATION_AND_AREA.xlsx
# Resolving censusindia.gov.in (censusindia.gov.in)... 103.151.152.84
# Connecting to censusindia.gov.in (censusindia.gov.in)|103.151.152.84|:443... connected.
# ERROR: cannot verify censusindia.gov.in's certificate, issued by ‘CN=RapidSSL TLS DV RSA Mixed SHA256 2020 CA-1,O=DigiCert Inc,C=US’:
#   Unable to locally verify the issuer's authority.
# To connect to censusindia.gov.in insecurely, use `--no-check-certificate'.

# %%
data = pd.read_excel('/content/A-1_NO_OF_VILLAGES_TOWNS_HOUSEHOLDS_POPULATION_AND_AREA.xlsx')
data.head()
# Out:
#   A-1 NUMBER OF VILLAGES, TOWNS, HOUSEHOLDS, POPULATION AND AREA  \
# 0                                        State  Code
# 1                                                NaN
# 2                                                  1
# 3                                                 00
# 4                                                 00
#
#       Unnamed: 1         Unnamed: 2  \
# 0  District Code  Sub District Code
# 1            NaN                NaN
# 2              2                  3
# 3            000              00000
# 4            000              00000
#
#                                           Unnamed: 3 Unnamed: 4  \
# 0  India/ State/ Union Territory/ District/ Sub-d...       Name
# 1                                                NaN        NaN
# 2                                                  4          5
# 3                                              INDIA   INDIA @&
# 4                                              INDIA    INDIA $
#
# ...

# %%
# columns = list(data.iloc[0])
# columns

# %%
replacer = {'\n':'',
            # '\':'',
            '/':''}
for key,value in replacer.items():
  # print(key,value)
  columns = map(lambda x: str(x).replace(key,value),columns)

# %%
col = list(columns)
col
# Out:
# ['State  Code',
#  'District Code',
#  'Sub District Code',
#  'India State Union Territory District Sub-district',
#  'Name',
#  'Total\nRural\nUrban',
#  'Number of villages',
#  'nan',
#  'Number of towns',
#  'Number of households',
#  'Population',
#  'nan',
#  'nan',
#  'Area\n (In sq. km)',
#  'Population per sq. km.']

# %%
data.columns
# Out:
# Index(['A-1 NUMBER OF VILLAGES, TOWNS, HOUSEHOLDS, POPULATION AND AREA',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14'],
#       dtype='object')

# %%
# dict = {}
# for i,j in zip(col,list(data.columns)):
#   dict[i] = j
# print(dict)
new = {j : i for (i,j) in zip(col,list(data.columns))} # dictionary comprehension

# %%
new
# Out:
# {'A-1 NUMBER OF VILLAGES, TOWNS, HOUSEHOLDS, POPULATION AND AREA': 'State  Code',
#  'Unnamed: 1': 'District Code',
#  'Unnamed: 2': 'Sub District Code',
#  'Unnamed: 3': 'India State Union Territory District Sub-district',
#  'Unnamed: 4': 'Name',
#  'Unnamed: 5': 'Total\nRural\nUrban',
#  'Unnamed: 6': 'Number of villages',
#  'Unnamed: 7': 'nan',
#  'Unnamed: 8': 'Number of towns',
#  'Unnamed: 9': 'Number of households',
#  'Unnamed: 10': 'Population',
#  'Unnamed: 11': 'nan',
#  'Unnamed: 12': 'nan',
#  'Unnamed: 13': 'Area\n (In sq. km)',
#  'Unnamed: 14': 'Population per sq. km.'}

# %%
data.rename(new,axis='columns',inplace = True)

# %%
# del(data.iloc[0])
data = data.iloc[1:]

# %%
data.head(2)
# Out:
#   State  Code District Code Sub District Code  \
# 1         NaN           NaN               NaN
# 2           1             2                 3
#
#   India State Union Territory District Sub-district Name Total\nRural\nUrban  \
# 1                                               NaN  NaN                 NaN
# 2                                                 4    5                   6
#
#   Number of villages          nan Number of towns Number of households  \
# 1          Inhabited  Uninhabited             NaN                  NaN
# 2                  7            8               9                   10
#
#   Population    nan      nan Area\n (In sq. km) Population per sq. km.
# 1    Persons  Males  Females                NaN                    NaN
# 2         11     12       13                 13                     14

# %%
data.isnull().sum()
# Out:
# State  Code                                           29
# District Code                                         11
# Sub District Code                                      7
# India State Union Territory District Sub-district     26
# Name                                                  26
# Total\nRural\nUrban                                   26
# Number of villages                                    28
# nan                                                   28
# Number of towns                                       29
# Number of households                                  29
# Population                                            28
# nan                                                   28
# nan                                                   28
# Area\n (In sq. km)                                   146
# Population per sq. km.                               146
# dtype: int64

# %%
data.shape
# Out:
# (20022, 15)

# %%
data.columns[-3],data.columns[-4]
# Out:
# ('nan', 'nan')

# %%
# data.columns[7]:'Uninhabited Villages',data.columns[-3]:'females',data.columns[-4]:'males'
col[7] = 'Uninhabited Villages'
col[-3] = 'females'
col[-4] = 'males'
col
# Out:
# ['State  Code',
#  'District Code',
#  'Sub District Code',
#  'India State Union Territory District Sub-district',
#  'Name',
#  'Total\nRural\nUrban',
#  'Number of villages',
#  'Uninhabited Villages',
#  'Number of towns',
#  'Number of households',
#  'Population',
#  'males',
#  'females',
#  'Area\n (In sq. km)',
#  'Population per sq. km.']

# %%
new = {j : i for (i,j) in zip(col,list(data.columns))}
new
# Out:
# {'A-1 NUMBER OF VILLAGES, TOWNS, HOUSEHOLDS, POPULATION AND AREA': 'State  Code',
#  'Unnamed: 1': 'District Code',
#  'Unnamed: 2': 'Sub District Code',
#  'Unnamed: 3': 'India State Union Territory District Sub-district',
#  'Unnamed: 4': 'Name',
#  'Unnamed: 5': 'Total\nRural\nUrban',
#  'Unnamed: 6': 'Number of villages',
#  'Unnamed: 7': 'Uninhabited Villages',
#  'Unnamed: 8': 'Number of towns',
#  'Unnamed: 9': 'Number of households',
#  'Unnamed: 10': 'Population',
#  'Unnamed: 11': 'males',
#  'Unnamed: 12': 'females',
#  'Unnamed: 13': 'Area\n (In sq. km)',
#  'Unnamed: 14': 'Population per sq. km.'}

# %%
data.rename(new,axis=1)
# Out:
#        State  Code  District Code  \
# 0      State  Code  District Code
# 1              NaN            NaN
# 2                1              2
# 3               00            000
# 4               00            000
# ...            ...            ...
# 20018          NaN            NaN
# 20019          NaN           (ii)
# 20020          NaN              5
# 20021          NaN            NaN
# 20022          NaN           NA -
#
#                                        Sub District Code  \
# 0                                      Sub District Code
# 1                                                    NaN
# 2                                                      3
# 3                                                  00000
# 4                                                  00000
# ...                                                  ...
# 20018  The same has also been done while working out ...
# 20019  Rural and Urban population of Arunachal Prades...
# ...

# %%
import numpy as np
import pandas as pd
from scipy import stats

# %%
from IPython.display import clear_output
# !wget https://raw.githubusercontent.com/Qian-Han/coursera-Applied-Data-Science-with-Python/master/Introduction-to-Data-Science-in-Python/original_data/grades.csv
clear_output()

# %%
df = pd.read_csv('grades.csv',sep=',')
df.head()
# Out:
#                              student_id  assignment1_grade  \
# 0  B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1  98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 2  D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3  FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 4  5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
#
#           assignment1_submission  assignment2_grade  \
# 0  2015-11-02 06:55:34.282000000          83.030552
# 1  2015-11-29 14:57:44.429000000          86.290821
# 2  2016-01-09 05:36:02.389000000          85.512541
# 3  2016-04-30 06:50:39.801000000          68.824532
# 4  2015-12-13 17:06:10.750000000          51.491040
#
#           assignment2_submission  assignment3_grade  \
# 0  2015-11-09 02:22:58.938000000          67.164441
# 1  2015-12-06 17:41:18.449000000          69.772657
# 2  2016-01-09 06:39:44.416000000          68.410033
# 3  2016-04-30 17:20:38.727000000          61.942079
# ...

# %%
df.shape
# Out:
# (2315, 13)

# %%
early = df[pd.to_datetime(df['assignment1_submission'])<'2016']
early
# Out:
#                                 student_id  assignment1_grade  \
# 0     B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1     98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 4     5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
# 5     D09000A0-827B-C0FF-3433-BF8FF286E15B          71.647278
# 8     C9D51293-BD58-F113-4167-A7C0BAFCB6E5          66.595568
# ...                                    ...                ...
# 2308  EFDA9F93-D0C3-864F-B0F6-2E9AA3E05E31          71.481182
# 2309  6D2AB78F-44F4-2E8B-5C5E-B79119BC7EAC          82.640274
# 2311  DE88902E-C7A7-E37A-CFA7-F2C8F2D219F2          75.367870
# 2312  EFDA9F93-D0C3-864F-B0F6-2E9AA3E05E31          73.269463
# 2314  DDE0526B-7DA4-80E8-C2A6-D097F3826029          80.318105
#
#              assignment1_submission  assignment2_grade  \
# 0     2015-11-02 06:55:34.282000000          83.030552
# 1     2015-11-29 14:57:44.429000000          86.290821
# ...

# %%
late_submitters = df[~df.index.isin(early.index)]
late_submitters
# Out:
#                                 student_id  assignment1_grade  \
# 2     D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3     FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 6     3217BE3F-E4B0-C3B6-9F64-462456819CE4          87.498744
# 7     F1CB5AA1-B3DE-5460-FAFF-BE951FD38B5F          80.576090
# 9     E2C617C2-4654-622C-AB50-1550C4BE42A0          59.270882
# ...                                    ...                ...
# 2303  DDE0526B-7DA4-80E8-C2A6-D097F3826029          97.215052
# 2306  DDE0526B-7DA4-80E8-C2A6-D097F3826029          47.696703
# 2307  1F51E050-78F7-F270-1B90-ED1BC0376763          94.595758
# 2310  DE88902E-C7A7-E37A-CFA7-F2C8F2D219F2          77.684611
# 2313  1F51E050-78F7-F270-1B90-ED1BC0376763          87.268366
#
#              assignment1_submission  assignment2_grade  \
# 2     2016-01-09 05:36:02.389000000          85.512541
# 3     2016-04-30 06:50:39.801000000          68.824532
# ...

# %%
late_submitters.shape
# Out:
# (1056, 13)

# %%
# ttest_
